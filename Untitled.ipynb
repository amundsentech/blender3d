# %%
import pandas as pd

# %%
pd. read_excel('DrillHole3d/data/Trek_North_Zone_DDH_Database_Master.xlsx')
# Out:
#       Order   Hole ID      Type  SampleID            QC     Reference  \
# 0         1  TRK08-01    Collar    COLLAR             0             0
# 1         2  TRK08-01  Interval  G0806743             0             0
# 2         3  TRK08-01  Interval  G0806744             0             0
# 3         4  TRK08-01  Interval  G0806745             0             0
# 4         5  TRK08-01  Interval  G0806746             0             0
# ...     ...       ...       ...       ...           ...           ...
# 1981   1982  TRK09-09  Interval   H138775             0             0
# 1982   1983  TRK09-09  Interval   H138776             0             0
# 1983   1984  TRK09-09  Interval   H138777             0             0
# 1984   1985  TRK09-09  Interval   H138778  H138779\nDUP             0
# 1985   1986  TRK09-09       EOH   H138780             0  Core Library
#
#            UTM_East     UTM_North  Azimuth   Dip  ...  Tl_ppm  U_ppm  V_ppm  \
# ...
